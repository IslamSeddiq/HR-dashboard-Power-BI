# %% [markdown]
# **Business Understanding**
#
# 1) The company is experiencing a high turnover rate, and leadership wants to understand who is leaving and why.
#
# 2) The company’s leadership wants to assess the effectiveness of senior leaders in retaining talent and managing high-performing teams.
#
# 3) HR wants to optimize the hiring process by identifying the most effective recruitment sources.
#
# 4) The leadership wants to understand diversity trends and whether they need to improve inclusivity in hiring.
#
# 5) There are concerns that some employees are working too many hours, leading to burnout and lower engagement.
#
# 6) The HR department suspects that high performers are not being fairly compensated.
#
# 7) HR wants to assess whether training programs are improving employee performance and retention.

# %%
import pandas as pd
df = pd.read_csv('/content/hr analytics data - employees attrition and leadership impact.csv')
df
# Out:
#        EmployeeID  DateOfHire DateOfBirth      Gender Department  \
# 0               1  22-03-2022  10-12-1966  Non-Binary         HR
# 1               2  11-01-2020  15-12-1965  Non-Binary         HR
# 2               3  30-10-2024  06-08-1964      Female  Marketing
# 3               4  18-11-2020  03-05-2001  Non-Binary  Marketing
# 4               5  13-05-2023  27-09-1993  Non-Binary         HR
# ...           ...         ...         ...         ...        ...
# 49995       49996  26-10-2018  11-10-1971  Non-Binary      Sales
# 49996       49997  07-10-2017  27-04-1977  Non-Binary    Finance
# 49997       49998  16-10-2023  02-01-1984  Non-Binary      Sales
# 49998       49999  22-09-2017  28-01-1985  Non-Binary         HR
# 49999       50000  18-02-2021  04-10-1978        Male         IT
#
#                                    JobTitle EmploymentStatus  SupervisorID  \
# 0         Sales promotion account executive           Active           115
# 1                           Sales executive       Terminated           419
# 2             Research officer, trade union           Active           241
# 3                            Soil scientist         On Leave           765
# 4                       Automotive engineer           Active           792
# ...                                     ...              ...           ...
# 49995                       Energy engineer         On Leave           815
# 49996                   Administrator, arts         On Leave           511
# 49997                  Biochemist, clinical         On Leave           359
# 49998           Careers information officer         On Leave           281
# 49999  Accountant, chartered public finance           Active           455
#
#         SupervisorName SupervisorLevel  ...  YearsSinceLastTraining  \
# 0      Michelle Dennis              VP  ...                       1
# 1        Thomas Nelson        Director  ...                       2
# 2       Miranda Barnes        Director  ...                       5
# 3        Cheryl Kelley        Director  ...                       2
# 4        Maria Jenkins              VP  ...                       1
# ...                ...             ...  ...                     ...
# 49995   Kaylee Edwards              VP  ...                       5
# 49996   Raymond Rogers         Manager  ...                       2
# 49997  Sarah Schroeder              VP  ...                       4
# 49998   Lisa Valentine              VP  ...                       5
# 49999      Marie Lopez        Director  ...                       4
#
#        JobSatisfactionScore  RetentionRisk  DiversityCategory  \
# 0                      1.45            Low        Non-Diverse
# 1                      1.40         Medium            Diverse
# 2                      4.46         Medium        Non-Diverse
# 3                      1.09         Medium        Non-Diverse
# 4                      3.21           High            Diverse
# ...                     ...            ...                ...
# 49995                  3.99           High            Diverse
# 49996                  4.86         Medium        Non-Diverse
# 49997                  1.97         Medium            Diverse
# 49998                  2.98            Low        Non-Diverse
# 49999                  2.81         Medium            Diverse
#
#        SkillsAssessmentScore  RecruitmentCost  TimeToFillPosition  \
# 0                      50.26          1152.71                  14
# 1                      97.90          2810.24                  23
# 2                      78.61          5945.55                  39
# 3                      95.29          7837.52                  25
# 4                      70.09          1638.29                  46
# ...                      ...              ...                 ...
# 49995                  69.31          4218.32                  33
# 49996                  65.73          6192.78                  32
# 49997                  66.81          4299.03                  45
# 49998                  58.21          9425.87                  52
# 49999                  76.28          6390.33                  10
#
#        InternalPromotion  WorkHoursPerWeek  StressLevelScore
# 0                    Yes                50              6.63
# 1                    Yes                50              5.68
# 2                     No                55              8.51
# 3                    Yes                56              3.34
# 4                     No                57              3.34
# ...                  ...               ...               ...
# 49995                Yes                31              9.83
# 49996                Yes                56              6.66
# 49997                 No                51              7.10
# 49998                Yes                31              8.39
# 49999                Yes                57              8.40
#
# [50000 rows x 40 columns]

# %% [markdown]
# **EDA ----> Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmployeeID                  50000 non-null  int64
#  1   DateOfHire                  50000 non-null  object
#  2   DateOfBirth                 50000 non-null  object
#  3   Gender                      50000 non-null  object
#  4   Department                  50000 non-null  object
#  5   JobTitle                    50000 non-null  object
#  6   EmploymentStatus            50000 non-null  object
#  7   SupervisorID                50000 non-null  int64
#  8   SupervisorName              50000 non-null  object
#  9   SupervisorLevel             50000 non-null  object
#  10  ProjectsAssigned            50000 non-null  int64
#  11  ProjectsCompleted           50000 non-null  int64
#  12  PerformanceRating           50000 non-null  int64
#  13  Salary                      50000 non-null  float64
#  14  Bonus                       50000 non-null  float64
#  15  YearsAtCompany              50000 non-null  int64
#  16  YearsInCurrentRole          50000 non-null  int64
#  17  TrainingHours               50000 non-null  int64
#  18  OvertimeHours               50000 non-null  int64
#  19  Absences                    50000 non-null  int64
#  20  HireSource                  50000 non-null  object
#  21  EmployeeEngagementScore     50000 non-null  float64
#  22  TerminationDate             16628 non-null  object
#  23  ReasonForLeaving            12365 non-null  object
#  24  LastPromotionDate           25073 non-null  object
#  25  SeniorLeader                50000 non-null  object
#  26  TeamSize                    50000 non-null  int64
#  27  PromotionCount              50000 non-null  int64
#  28  WorkFromHomeDays            50000 non-null  int64
#  29  PerformanceImprovementPlan  50000 non-null  object
#  30  YearsSinceLastTraining      50000 non-null  int64
#  31  JobSatisfactionScore        50000 non-null  float64
#  32  RetentionRisk               50000 non-null  object
#  33  DiversityCategory           50000 non-null  object
#  34  SkillsAssessmentScore       50000 non-null  float64
#  35  RecruitmentCost             50000 non-null  float64
#  36  TimeToFillPosition          50000 non-null  int64
#  37  InternalPromotion           50000 non-null  object
#  38  WorkHoursPerWeek            50000 non-null  int64
#  39  StressLevelScore            50000 non-null  float64
# dtypes: float64(7), int64(16), object(17)
# memory usage: 15.3+ MB

# %%
df.head(10)
# Out:
#    EmployeeID  DateOfHire DateOfBirth      Gender Department  \
# 0           1  22-03-2022  10-12-1966  Non-Binary         HR
# 1           2  11-01-2020  15-12-1965  Non-Binary         HR
# 2           3  30-10-2024  06-08-1964      Female  Marketing
# 3           4  18-11-2020  03-05-2001  Non-Binary  Marketing
# 4           5  13-05-2023  27-09-1993  Non-Binary         HR
# 5           6  13-09-2024  28-08-1972        Male      Sales
# 6           7  20-02-2024  19-07-1964      Female         IT
# 7           8  23-05-2017  29-11-2005  Non-Binary         HR
# 8           9  31-08-2018  03-04-1995      Female  Marketing
# 9          10  05-04-2021  20-02-1989  Non-Binary      Sales
#
#                             JobTitle EmploymentStatus  SupervisorID  \
# 0  Sales promotion account executive           Active           115
# 1                    Sales executive       Terminated           419
# 2      Research officer, trade union           Active           241
# 3                     Soil scientist         On Leave           765
# 4                Automotive engineer           Active           792
# 5             Race relations officer       Terminated           249
# 6                         Podiatrist       Terminated           367
# 7              Merchant navy officer           Active           555
# 8              Multimedia programmer         On Leave           546
# 9           Print production planner         On Leave           342
#
#           SupervisorName SupervisorLevel  ...  YearsSinceLastTraining  \
# 0        Michelle Dennis              VP  ...                       1
# 1          Thomas Nelson        Director  ...                       2
# 2         Miranda Barnes        Director  ...                       5
# 3          Cheryl Kelley        Director  ...                       2
# 4          Maria Jenkins              VP  ...                       1
# 5         Kristin Kelley              VP  ...                       2
# 6         Julie Valencia              VP  ...                       2
# 7        Brenda Hamilton         Manager  ...                       2
# 8  Michael Zimmerman Jr.         Manager  ...                       5
# 9      Mrs. Joyce Wilson              VP  ...                       2
#
#    JobSatisfactionScore  RetentionRisk  DiversityCategory  \
# 0                  1.45            Low        Non-Diverse
# 1                  1.40         Medium            Diverse
# 2                  4.46         Medium        Non-Diverse
# 3                  1.09         Medium        Non-Diverse
# 4                  3.21           High            Diverse
# 5                  4.43            Low            Diverse
# 6                  2.53         Medium            Diverse
# 7                  2.56         Medium            Diverse
# 8                  3.41         Medium        Non-Diverse
# 9                  4.46            Low        Non-Diverse
#
#    SkillsAssessmentScore  RecruitmentCost  TimeToFillPosition  \
# 0                  50.26          1152.71                  14
# 1                  97.90          2810.24                  23
# 2                  78.61          5945.55                  39
# 3                  95.29          7837.52                  25
# 4                  70.09          1638.29                  46
# 5                  55.33          9943.64                  52
# 6                  84.93          5566.87                  11
# 7                  91.76          4887.04                  36
# 8                  91.18          6198.65                  37
# 9                  55.70          1763.61                  23
#
#    InternalPromotion  WorkHoursPerWeek  StressLevelScore
# 0                Yes                50              6.63
# 1                Yes                50              5.68
# 2                 No                55              8.51
# 3                Yes                56              3.34
# 4                 No                57              3.34
# 5                 No                57              2.07
# 6                 No                38              5.48
# 7                 No                57              9.99
# 8                 No                43              5.91
# 9                 No                48              1.80
#
# [10 rows x 40 columns]

# %%
df.tail(10)
# Out:
#        EmployeeID  DateOfHire DateOfBirth      Gender Department  \
# 49990       49991  17-07-2015  10-07-1996  Non-Binary         IT
# 49991       49992  15-11-2022  20-10-1967  Non-Binary         HR
# 49992       49993  04-12-2017  06-06-1999  Non-Binary      Sales
# 49993       49994  30-03-2021  16-05-1993      Female      Sales
# 49994       49995  06-11-2018  15-10-1973        Male  Marketing
# 49995       49996  26-10-2018  11-10-1971  Non-Binary      Sales
# 49996       49997  07-10-2017  27-04-1977  Non-Binary    Finance
# 49997       49998  16-10-2023  02-01-1984  Non-Binary      Sales
# 49998       49999  22-09-2017  28-01-1985  Non-Binary         HR
# 49999       50000  18-02-2021  04-10-1978        Male         IT
#
#                                    JobTitle EmploymentStatus  SupervisorID  \
# 49990                        Data scientist           Active           196
# 49991                           Pathologist       Terminated           813
# 49992                 Geneticist, molecular       Terminated           191
# 49993                  Public house manager           Active           492
# 49994                      Fashion designer         On Leave           356
# 49995                       Energy engineer         On Leave           815
# 49996                   Administrator, arts         On Leave           511
# 49997                  Biochemist, clinical         On Leave           359
# 49998           Careers information officer         On Leave           281
# 49999  Accountant, chartered public finance           Active           455
#
#          SupervisorName SupervisorLevel  ...  YearsSinceLastTraining  \
# 49990   Bonnie Humphrey         Manager  ...                       1
# 49991  Jessica Mccarthy         Manager  ...                       3
# 49992     Amanda Flores              VP  ...                       4
# 49993      Susan Osborn              VP  ...                       2
# 49994    Heather Davies         Manager  ...                       0
# 49995    Kaylee Edwards              VP  ...                       5
# 49996    Raymond Rogers         Manager  ...                       2
# 49997   Sarah Schroeder              VP  ...                       4
# 49998    Lisa Valentine              VP  ...                       5
# 49999       Marie Lopez        Director  ...                       4
#
#        JobSatisfactionScore  RetentionRisk  DiversityCategory  \
# 49990                  4.31         Medium        Non-Diverse
# 49991                  3.50           High            Diverse
# 49992                  1.60            Low            Diverse
# 49993                  3.92            Low        Non-Diverse
# 49994                  1.16            Low            Diverse
# 49995                  3.99           High            Diverse
# 49996                  4.86         Medium        Non-Diverse
# 49997                  1.97         Medium            Diverse
# 49998                  2.98            Low        Non-Diverse
# 49999                  2.81         Medium            Diverse
#
#        SkillsAssessmentScore  RecruitmentCost  TimeToFillPosition  \
# 49990                  61.97          9606.35                  10
# 49991                  70.74          2006.76                  19
# 49992                  89.35          8738.06                  26
# 49993                  86.75          2217.65                  13
# 49994                  67.16          3812.39                   7
# 49995                  69.31          4218.32                  33
# 49996                  65.73          6192.78                  32
# 49997                  66.81          4299.03                  45
# 49998                  58.21          9425.87                  52
# 49999                  76.28          6390.33                  10
#
#        InternalPromotion  WorkHoursPerWeek  StressLevelScore
# 49990                Yes                55              5.66
# 49991                Yes                40              4.99
# 49992                Yes                32              6.54
# 49993                 No                38              4.56
# 49994                 No                36              7.17
# 49995                Yes                31              9.83
# 49996                Yes                56              6.66
# 49997                 No                51              7.10
# 49998                Yes                31              8.39
# 49999                Yes                57              8.40
#
# [10 rows x 40 columns]

# %%
df.describe()
# Out:
#          EmployeeID  SupervisorID  ProjectsAssigned  ProjectsCompleted  \
# count  50000.000000  50000.000000      50000.000000       50000.000000
# mean   25000.500000    500.497060         10.028620          10.012900
# std    14433.901067    288.080807          6.053701           6.042273
# min        1.000000      1.000000          0.000000           0.000000
# 25%    12500.750000    250.000000          5.000000           5.000000
# 50%    25000.500000    502.000000         10.000000          10.000000
# 75%    37500.250000    749.000000         15.000000          15.000000
# max    50000.000000   1000.000000         20.000000          20.000000
#
#        PerformanceRating         Salary         Bonus  YearsAtCompany  \
# count       50000.000000   50000.000000  50000.000000    50000.000000
# mean            2.997480   75090.043952  10029.174125        5.002400
# std             1.416825   25868.273525   5786.474683        3.173836
# min             1.000000   30000.200000      0.250000        0.000000
# 25%             2.000000   52884.180000   5034.715000        2.000000
# 50%             3.000000   75245.525000  10027.525000        5.000000
# 75%             4.000000   97426.855000  15036.405000        8.000000
# max             5.000000  119994.800000  19999.910000       10.000000
#
#        YearsInCurrentRole  TrainingHours  ...      TeamSize  PromotionCount  \
# count        50000.000000   50000.000000  ...  50000.000000    50000.000000
# mean             5.004720      50.100900  ...     27.420280        2.496860
# std              3.168807      29.109243  ...     13.324633        1.711645
# min              0.000000       0.000000  ...      5.000000        0.000000
# 25%              2.000000      25.000000  ...     16.000000        1.000000
# 50%              5.000000      50.000000  ...     27.000000        2.000000
# 75%              8.000000      75.000000  ...     39.000000        4.000000
# max             10.000000     100.000000  ...     50.000000        5.000000
#
#        WorkFromHomeDays  YearsSinceLastTraining  JobSatisfactionScore  \
# count      50000.000000            50000.000000          50000.000000
# mean          10.002640                2.488620              2.991840
# std            6.047919                1.711493              1.154465
# min            0.000000                0.000000              1.000000
# 25%            5.000000                1.000000              1.990000
# 50%           10.000000                2.000000              2.980000
# 75%           15.000000                4.000000              4.000000
# max           20.000000                5.000000              5.000000
#
#        SkillsAssessmentScore  RecruitmentCost  TimeToFillPosition  \
# count           50000.000000     50000.000000        50000.000000
# mean               74.966885      5477.197624           32.483960
# std                14.420894      2598.414504           16.180595
# min                50.000000      1000.530000            5.000000
# 25%                62.540000      3219.140000           19.000000
# 50%                74.950000      5469.020000           32.000000
# 75%                87.430000      7724.915000           47.000000
# max               100.000000      9999.950000           60.000000
#
#        WorkHoursPerWeek  StressLevelScore
# count      50000.000000      50000.000000
# mean          44.987400          5.511490
# std            8.947637          2.602615
# min           30.000000          1.000000
# 25%           37.000000          3.250000
# 50%           45.000000          5.530000
# 75%           53.000000          7.760000
# max           60.000000         10.000000
#
# [8 rows x 23 columns]

# %%
df.nunique()
# Out:
# EmployeeID                    50000
# DateOfHire                     3653
# DateOfBirth                   16556
# Gender                            3
# Department                        5
# JobTitle                        639
# EmploymentStatus                  3
# SupervisorID                   1000
# SupervisorName                40158
# SupervisorLevel                   3
# ProjectsAssigned                 21
# ProjectsCompleted                21
# PerformanceRating                 5
# Salary                        49869
# Bonus                         49362
# YearsAtCompany                   11
# YearsInCurrentRole               11
# TrainingHours                   101
# OvertimeHours                    51
# Absences                         21
# HireSource                        4
# EmployeeEngagementScore         401
# TerminationDate                2983
# ReasonForLeaving                  3
# LastPromotionDate              3180
# SeniorLeader                      3
# TeamSize                         46
# PromotionCount                    6
# WorkFromHomeDays                 21
# PerformanceImprovementPlan        2
# YearsSinceLastTraining            6
# JobSatisfactionScore            401
# RetentionRisk                     3
# DiversityCategory                 2
# SkillsAssessmentScore          5001
# RecruitmentCost               48625
# TimeToFillPosition               56
# InternalPromotion                 2
# WorkHoursPerWeek                 31
# StressLevelScore                901
# dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# EmployeeID                      int64
# DateOfHire                     object
# DateOfBirth                    object
# Gender                         object
# Department                     object
# JobTitle                       object
# EmploymentStatus               object
# SupervisorID                    int64
# SupervisorName                 object
# SupervisorLevel                object
# ProjectsAssigned                int64
# ProjectsCompleted               int64
# PerformanceRating               int64
# Salary                        float64
# Bonus                         float64
# YearsAtCompany                  int64
# YearsInCurrentRole              int64
# TrainingHours                   int64
# OvertimeHours                   int64
# Absences                        int64
# HireSource                     object
# EmployeeEngagementScore       float64
# TerminationDate                object
# ReasonForLeaving               object
# LastPromotionDate              object
# SeniorLeader                   object
# TeamSize                        int64
# PromotionCount                  int64
# WorkFromHomeDays                int64
# PerformanceImprovementPlan     object
# YearsSinceLastTraining          int64
# JobSatisfactionScore          float64
# RetentionRisk                  object
# DiversityCategory              object
# SkillsAssessmentScore         float64
# RecruitmentCost               float64
# TimeToFillPosition              int64
# InternalPromotion              object
# WorkHoursPerWeek                int64
# StressLevelScore              float64
# dtype: object

# %%
# Check nulls
df.isnull().sum()
# Out:
# EmployeeID                        0
# DateOfHire                        0
# DateOfBirth                       0
# Gender                            0
# Department                        0
# JobTitle                          0
# EmploymentStatus                  0
# SupervisorID                      0
# SupervisorName                    0
# SupervisorLevel                   0
# ProjectsAssigned                  0
# ProjectsCompleted                 0
# PerformanceRating                 0
# Salary                            0
# Bonus                             0
# YearsAtCompany                    0
# YearsInCurrentRole                0
# TrainingHours                     0
# OvertimeHours                     0
# Absences                          0
# HireSource                        0
# EmployeeEngagementScore           0
# TerminationDate               33372
# ReasonForLeaving              37635
# LastPromotionDate             24927
# SeniorLeader                      0
# TeamSize                          0
# PromotionCount                    0
# WorkFromHomeDays                  0
# PerformanceImprovementPlan        0
# YearsSinceLastTraining            0
# JobSatisfactionScore              0
# RetentionRisk                     0
# DiversityCategory                 0
# SkillsAssessmentScore             0
# RecruitmentCost                   0
# TimeToFillPosition                0
# InternalPromotion                 0
# WorkHoursPerWeek                  0
# StressLevelScore                  0
# dtype: int64

# %%
# Calculate the percentage of nulls
((pd.DataFrame({'Pct_Null':df.isnull().sum()})) / df.shape[0]) * 100
# Out:
#                             Pct_Null
# EmployeeID                     0.000
# DateOfHire                     0.000
# DateOfBirth                    0.000
# Gender                         0.000
# Department                     0.000
# JobTitle                       0.000
# EmploymentStatus               0.000
# SupervisorID                   0.000
# SupervisorName                 0.000
# SupervisorLevel                0.000
# ProjectsAssigned               0.000
# ProjectsCompleted              0.000
# PerformanceRating              0.000
# Salary                         0.000
# Bonus                          0.000
# YearsAtCompany                 0.000
# YearsInCurrentRole             0.000
# TrainingHours                  0.000
# OvertimeHours                  0.000
# Absences                       0.000
# HireSource                     0.000
# EmployeeEngagementScore        0.000
# TerminationDate               66.744
# ReasonForLeaving              75.270
# LastPromotionDate             49.854
# SeniorLeader                   0.000
# TeamSize                       0.000
# PromotionCount                 0.000
# WorkFromHomeDays               0.000
# PerformanceImprovementPlan     0.000
# YearsSinceLastTraining         0.000
# JobSatisfactionScore           0.000
# RetentionRisk                  0.000
# DiversityCategory              0.000
# SkillsAssessmentScore          0.000
# RecruitmentCost                0.000
# TimeToFillPosition             0.000
# InternalPromotion              0.000
# WorkHoursPerWeek               0.000
# StressLevelScore               0.000

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Removing the EmployeeID column to ensure that no duplicates
df.drop(columns = 'EmployeeID', inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['DateOfHire', 'DateOfBirth', 'Gender', 'Department', 'JobTitle',
#        'EmploymentStatus', 'SupervisorID', 'SupervisorName', 'SupervisorLevel',
#        'ProjectsAssigned', 'ProjectsCompleted', 'PerformanceRating', 'Salary',
#        'Bonus', 'YearsAtCompany', 'YearsInCurrentRole', 'TrainingHours',
#        'OvertimeHours', 'Absences', 'HireSource', 'EmployeeEngagementScore',
#        'TerminationDate', 'ReasonForLeaving', 'LastPromotionDate',
#        'SeniorLeader', 'TeamSize', 'PromotionCount', 'WorkFromHomeDays',
#        'PerformanceImprovementPlan', 'YearsSinceLastTraining',
#        'JobSatisfactionScore', 'RetentionRisk', 'DiversityCategory',
#        'SkillsAssessmentScore', 'RecruitmentCost', 'TimeToFillPosition',
#        'InternalPromotion', 'WorkHoursPerWeek', 'StressLevelScore'],
#       dtype='object')

# %% [markdown]
# **Check irrelevant columns:**
#
# (SupervisorID, SupervisorName, and SupervisorLevel, YearsAtCompany, YearsInCurrentRole, LastPromotionDate, PromotionCount, InternalPromotion)
#
# where we are not analyzing any thing related to these columns

# %% [markdown]
# **preprocessing (cleaning data)**

# %% [markdown]
# **Removing irrelevant columns**

# %%
df.drop(columns = ['SupervisorID', 'SupervisorName', 'SupervisorLevel', 'YearsAtCompany', 'YearsInCurrentRole',
                   'LastPromotionDate', 'PromotionCount', 'InternalPromotion'], inplace = True)

# %%
df.columns
# Out:
# Index(['DateOfHire', 'DateOfBirth', 'Gender', 'Department', 'JobTitle',
#        'EmploymentStatus', 'ProjectsAssigned', 'ProjectsCompleted',
#        'PerformanceRating', 'Salary', 'Bonus', 'TrainingHours',
#        'OvertimeHours', 'Absences', 'HireSource', 'EmployeeEngagementScore',
#        'TerminationDate', 'ReasonForLeaving', 'SeniorLeader', 'TeamSize',
#        'WorkFromHomeDays', 'PerformanceImprovementPlan',
#        'YearsSinceLastTraining', 'JobSatisfactionScore', 'RetentionRisk',
#        'DiversityCategory', 'SkillsAssessmentScore', 'RecruitmentCost',
#        'TimeToFillPosition', 'WorkHoursPerWeek', 'StressLevelScore'],
#       dtype='object')

# %%
df.shape[1]
# Out:
# 31

# %%
df.drop(df[df['Gender'] == 'Non-Binary'].index, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      16792
# Female    16540
# Name: count, dtype: int64

# %% [markdown]
# **Handling Data Types**

# %%
# Converting datatype to datetime format
# dayfirst = True ------> Ensures that the day is correctly interpreted when ambiguous.
# errors = 'coerce' ----> convert the datatype from nulls to NaT
df['DateOfBirth'] = pd.to_datetime(df['DateOfBirth'], dayfirst = True, errors = 'coerce')
df['DateOfHire'] = pd.to_datetime(df['DateOfHire'], dayfirst = True, errors = 'coerce')
df['TerminationDate'] = pd.to_datetime(df['TerminationDate'], dayfirst = True, errors = 'coerce')

# %%
df.dtypes
# Out:
# DateOfHire                    datetime64[ns]
# DateOfBirth                   datetime64[ns]
# Gender                                object
# Department                            object
# JobTitle                              object
# EmploymentStatus                      object
# ProjectsAssigned                       int64
# ProjectsCompleted                      int64
# PerformanceRating                      int64
# Salary                               float64
# Bonus                                float64
# TrainingHours                          int64
# OvertimeHours                          int64
# Absences                               int64
# HireSource                            object
# EmployeeEngagementScore              float64
# TerminationDate               datetime64[ns]
# ReasonForLeaving                      object
# SeniorLeader                          object
# TeamSize                               int64
# WorkFromHomeDays                       int64
# PerformanceImprovementPlan            object
# YearsSinceLastTraining                 int64
# JobSatisfactionScore                 float64
# RetentionRisk                         object
# DiversityCategory                     object
# SkillsAssessmentScore                float64
# RecruitmentCost                      float64
# TimeToFillPosition                     int64
# WorkHoursPerWeek                       int64
# StressLevelScore                     float64
# dtype: object

# %% [markdown]
# **Handling Nulls**

# %%
# Calculate the percentage of nulls
((pd.DataFrame({'Pct_Null':df.isnull().sum()})) / df.shape[0]) * 100
# Out:
#                              Pct_Null
# DateOfHire                   0.000000
# DateOfBirth                  0.000000
# Gender                       0.000000
# Department                   0.000000
# JobTitle                     0.000000
# EmploymentStatus             0.000000
# ProjectsAssigned             0.000000
# ProjectsCompleted            0.000000
# PerformanceRating            0.000000
# Salary                       0.000000
# Bonus                        0.000000
# TrainingHours                0.000000
# OvertimeHours                0.000000
# Absences                     0.000000
# HireSource                   0.000000
# EmployeeEngagementScore      0.000000
# TerminationDate             66.770671
# ReasonForLeaving            75.351014
# SeniorLeader                 0.000000
# TeamSize                     0.000000
# WorkFromHomeDays             0.000000
# PerformanceImprovementPlan   0.000000
# YearsSinceLastTraining       0.000000
# JobSatisfactionScore         0.000000
# RetentionRisk                0.000000
# DiversityCategory            0.000000
# SkillsAssessmentScore        0.000000
# RecruitmentCost              0.000000
# TimeToFillPosition           0.000000
# WorkHoursPerWeek             0.000000
# StressLevelScore             0.000000

# %%
df.loc[(df["TerminationDate"].isnull()) & (df["ReasonForLeaving"].isnull()), "ReasonForLeaving"] = "Still Employed"

# %%
df.loc[(df["TerminationDate"].isnull()) & (df["ReasonForLeaving"].isnull())].shape[0]
# Out:
# 0

# %%
df.loc[(df["TerminationDate"].notnull()) & (df["ReasonForLeaving"].isnull())].shape[0]
# Out:
# 2860

# %%
df.loc[(df['TerminationDate'].notnull()) & (df['ReasonForLeaving'].isnull()), 'ReasonForLeaving'] = 'No Reason'

# %%
df.loc[(df["TerminationDate"].notnull()) & (df["ReasonForLeaving"].isnull())].shape[0]
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# DateOfHire                        0
# DateOfBirth                       0
# Gender                            0
# Department                        0
# JobTitle                          0
# EmploymentStatus                  0
# ProjectsAssigned                  0
# ProjectsCompleted                 0
# PerformanceRating                 0
# Salary                            0
# Bonus                             0
# TrainingHours                     0
# OvertimeHours                     0
# Absences                          0
# HireSource                        0
# EmployeeEngagementScore           0
# TerminationDate               22256
# ReasonForLeaving                  0
# SeniorLeader                      0
# TeamSize                          0
# WorkFromHomeDays                  0
# PerformanceImprovementPlan        0
# YearsSinceLastTraining            0
# JobSatisfactionScore              0
# RetentionRisk                     0
# DiversityCategory                 0
# SkillsAssessmentScore             0
# RecruitmentCost                   0
# TimeToFillPosition                0
# WorkHoursPerWeek                  0
# StressLevelScore                  0
# dtype: int64

# %%
df["TerminationDate"]
# Out:
# 2              NaT
# 5       2024-09-17
# 6       2025-01-25
# 8              NaT
# 10             NaT
#            ...
# 49986   2025-01-25
# 49989          NaT
# 49993          NaT
# 49994          NaT
# 49999          NaT
# Name: TerminationDate, Length: 33332, dtype: datetime64[ns]

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.2)
# Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.5 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.1.0

# %%
from faker import Faker
import random

fake = Faker()

def generate_name(gender):
    if gender == 'Male':
        return fake.name_male()
    elif gender == 'Female':
        return fake.name_female()
    else:
        return fake.name()

df['EmployeeName'] = df['Gender'].apply(generate_name)

# %%
df['EmployeeName']
# Out:
# 2            Ashley Clark
# 5           William Adams
# 6            Brenda Solis
# 8          Vanessa Potter
# 10       Dr. Megan Parker
#                ...
# 49986       Eric Anderson
# 49989      Michelle Pratt
# 49993       Barbara Smith
# 49994       Brian Griffin
# 49999        David Bryant
# Name: EmployeeName, Length: 33332, dtype: object

# %%
new_order = ['EmployeeName', 'DateOfHire', 'DateOfBirth', 'Gender', 'Department', 'JobTitle',
       'EmploymentStatus', 'ProjectsAssigned', 'ProjectsCompleted', 'PerformanceRating', 'Salary',
       'Bonus', 'TrainingHours', 'OvertimeHours', 'Absences', 'HireSource', 'EmployeeEngagementScore',
       'TerminationDate', 'ReasonForLeaving', 'SeniorLeader', 'TeamSize', 'WorkFromHomeDays',
       'PerformanceImprovementPlan', 'YearsSinceLastTraining',
       'JobSatisfactionScore', 'RetentionRisk', 'DiversityCategory',
       'SkillsAssessmentScore', 'RecruitmentCost', 'TimeToFillPosition',
       'WorkHoursPerWeek', 'StressLevelScore']
df = df.reindex(columns = new_order)
df
# Out:
#            EmployeeName DateOfHire DateOfBirth  Gender Department  \
# 2          Ashley Clark 2024-10-30  1964-08-06  Female  Marketing
# 5         William Adams 2024-09-13  1972-08-28    Male      Sales
# 6          Brenda Solis 2024-02-20  1964-07-19  Female         IT
# 8        Vanessa Potter 2018-08-31  1995-04-03  Female  Marketing
# 10     Dr. Megan Parker 2018-06-03  1959-10-03  Female         HR
# ...                 ...        ...         ...     ...        ...
# 49986     Eric Anderson 2024-07-11  1990-03-19    Male      Sales
# 49989    Michelle Pratt 2017-12-05  1989-04-28  Female    Finance
# 49993     Barbara Smith 2021-03-30  1993-05-16  Female      Sales
# 49994     Brian Griffin 2018-11-06  1973-10-15    Male  Marketing
# 49999      David Bryant 2021-02-18  1978-10-04    Male         IT
#
#                                                 JobTitle EmploymentStatus  \
# 2                          Research officer, trade union           Active
# 5                                 Race relations officer       Terminated
# 6                                             Podiatrist       Terminated
# 8                                  Multimedia programmer         On Leave
# 10                                     Quantity surveyor         On Leave
# ...                                                  ...              ...
# 49986                                            Curator       Terminated
# 49989  Clinical scientist, histocompatibility and imm...           Active
# 49993                               Public house manager           Active
# 49994                                   Fashion designer         On Leave
# 49999               Accountant, chartered public finance           Active
#
#        ProjectsAssigned  ProjectsCompleted  PerformanceRating  ...  \
# 2                     9                  4                  5  ...
# 5                     0                 12                  3  ...
# 6                    18                  6                  1  ...
# 8                    19                 13                  5  ...
# 10                    0                 17                  3  ...
# ...                 ...                ...                ...  ...
# 49986                11                 19                  5  ...
# 49989                15                 15                  3  ...
# 49993                13                  2                  1  ...
# 49994                18                  2                  3  ...
# 49999                 3                 12                  3  ...
#
#        PerformanceImprovementPlan  YearsSinceLastTraining  \
# 2                             Yes                       5
# 5                             Yes                       2
# 6                              No                       2
# 8                              No                       5
# 10                            Yes                       1
# ...                           ...                     ...
# 49986                         Yes                       3
# 49989                         Yes                       2
# 49993                          No                       2
# 49994                          No                       0
# 49999                          No                       4
#
#        JobSatisfactionScore  RetentionRisk  DiversityCategory  \
# 2                      4.46         Medium        Non-Diverse
# 5                      4.43            Low            Diverse
# 6                      2.53         Medium            Diverse
# 8                      3.41         Medium        Non-Diverse
# 10                     4.71            Low        Non-Diverse
# ...                     ...            ...                ...
# 49986                  1.63         Medium        Non-Diverse
# 49989                  3.65         Medium        Non-Diverse
# 49993                  3.92            Low        Non-Diverse
# 49994                  1.16            Low            Diverse
# 49999                  2.81         Medium            Diverse
#
#       SkillsAssessmentScore  RecruitmentCost TimeToFillPosition  \
# 2                     78.61          5945.55                 39
# 5                     55.33          9943.64                 52
# 6                     84.93          5566.87                 11
# 8                     91.18          6198.65                 37
# 10                    55.26          2252.78                  6
# ...                     ...              ...                ...
# 49986                 73.62          4831.94                 59
# 49989                 51.68          4287.98                 32
# 49993                 86.75          2217.65                 13
# 49994                 67.16          3812.39                  7
# 49999                 76.28          6390.33                 10
#
#       WorkHoursPerWeek StressLevelScore
# 2                   55             8.51
# 5                   57             2.07
# 6                   38             5.48
# 8                   43             5.91
# 10                  58             4.72
# ...                ...              ...
# 49986               35             7.71
# 49989               40             1.35
# 49993               38             4.56
# 49994               36             7.17
# 49999               57             8.40
#
# [33332 rows x 32 columns]

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
HireSource_counts = df['HireSource'].value_counts()

#Pie Chart
plt.figure(figsize=(6,6))
plt.pie(HireSource_counts, labels=HireSource_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Hire Sources')
plt.axis('equal')
plt.show()

# %%
gender_counts = df['Gender'].value_counts()

#Bar Chart
gender_counts.plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Gender')
plt.xlabel('Gender')
plt.ylabel('Total')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(9, 5))

# Histogram of Salary
sns.histplot(df['Salary'], bins=10, kde=True, ax=axes[0, 0], color='blue')
axes[0, 0].set_title('Salary Distribution (Histogram)')
axes[0, 0].set_xlabel('Salary')

# Box Plot of Bonus
sns.histplot(x=df['Bonus'], kde=True, ax=axes[0, 1], color='orange')
axes[0, 1].set_title('Box Plot of Bonus')
axes[0, 1].set_xlabel('Bonus')

# Box Plot of Overtime Hours
sns.boxplot(x=df['OvertimeHours'], ax=axes[1, 0], color='green')
axes[1, 0].set_title('Box Plot of Overtime Hours')
axes[1, 0].set_xlabel('Overtime Hours')

# Box Plot of Absences
sns.boxplot(x=df['Absences'], ax=axes[1, 1], color='red')
axes[1, 1].set_title('Box Plot of Absences')
axes[1, 1].set_xlabel('Absences')

plt.tight_layout()
plt.show()

# %%
plt.hist(df['SkillsAssessmentScore'], bins=10, color='purple', edgecolor='black')
plt.title('Distribution of Skills Assessment Scores')
plt.xlabel('Score')
plt.ylabel('Number of People')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df.to_csv('HR Data1.csv', index=False)
